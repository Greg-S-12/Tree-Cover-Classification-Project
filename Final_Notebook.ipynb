# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from IPython.display import Image  
from pydotplus import graph_from_dot_data
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import seaborn as sns
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score
import DataFunctions_greg as fc
# Out:
# Logistic Regression
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0675b4fada6d> in <module>()
#      36 from scipy import interp
#      37 from sklearn.metrics import roc_auc_score
# ---> 38 import DataFunctions_greg as fc
#
# ~/Flatiron DS/Forest_Tree_Types/DataFunctions_greg.py in <module>()
#     165 print("\nLogistic Regression")
#     166 # assuming your already have a list of actual_class and predicted_class from the logistic regression classifier
# --> 167 lr_roc_auc_multiclass = roc_auc_score_multiclass(actual_class, predicted_class)
#     168 print(lr_roc_auc_multiclass)
#     169
#
# NameError: name 'actual_class' is not defined

# %%
df = pd.read_csv('~/Downloads/covtype.csv')
df.head()

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# Baseline model

# %%
y = df['Cover_Type']
X = df.loc[:, df.columns != 'Cover_Type']
list_of_classes = [1, 2, 3, 4, 5, 6, 7]

# %%
lr_model = LogisticRegression(fit_intercept=False,
                                 C=1e12,class_weight='balanced', solver='liblinear')
                           
fc.multiclass_classifier(X,y,lr_model,list_of_classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-be3d2085e636> in <module>()
#       2                                  C=1e12,class_weight='balanced', solver='liblinear')
#       3
# ----> 4 fc.multiclass_classifier(X,y,model,list_of_classes)
#
# ~/Flatiron DS/Forest_Tree_Types/DataFunctions_greg.py in multiclass_classifier(X, y, model, list_of_classes)
#     239
#     240
# --> 241     sk_report = classification_report(digits=6,y_true=y_test, y_pred = y_prob)
#     242
#     243
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/metrics/classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict)
#    1850     """
#    1851
# -> 1852     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1853
#    1854     labels_given = True
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %%
dt_model  = DecisionTreeClassifier(criterion='gini', max_depth=23,class_weight='balanced' )

# %%
fc.multiclass_classifier_decision_tree(X,y,dt_model,list_of_classes)
# Out:
# One-vs-Rest ROC AUC scores:
# 0.962477 (macro),
# 0.957426 (weighted by prevalence)
# (None, None)

# %%
svm_model = svm.SVC(kernel='linear', probability=True,
                                 random_state=42, max_iter=500)

fc.multiclass_classifier(X,y,svm_model,list_of_classes)
